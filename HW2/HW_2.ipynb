# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# Put your name here:
# *  Pranit Ahuja
#
# When you encounter questions in the text below, open a markdown cell in that problem area and put your answers.
#
# This HW is due Friday at midnight in D2L.

# %% [markdown]
# ____
# # HW #2: Review and Pandas
# ____

# %% [markdown]
# ✍🏻 **Problem 1, Pandas Indexing**: Describe multi-indexing in Pandas, using a code example in your explanation. You should have a markdown cell and a code cell.

# %% [markdown]
# Multi-indexing, also known as hierarchical indexing allows you to work with higher-dimensional data in a more structured way. It enables you to create DataFrames with multiple levels of row and column indices, which can be especially useful when dealing with complex datasets.

# %%
data = {
    'Team': ['Ferrari', 'Ferrari', 'Mercedes', 'Mercedes', 'Red Bull', 'Red Bull', 'McLaren', 'McLaren'],
    'Driver': ['Sainz', 'Leclerc', 'Hamilton', 'Russel', 'Verstappen', 'Perez', 'Norris', 'Piastri'],
    'Points': [117, 111, 164, 109, 364, 219, 79, 36]
}

df = pd.DataFrame(data)
df.set_index(['Team', 'Driver'], inplace=True)
df
# Out:
#                      Points
# Team     Driver
# Ferrari  Sainz          117
#          Leclerc        111
# Mercedes Hamilton       164
#          Russel         109
# Red Bull Verstappen     364
#          Perez          219
# McLaren  Norris          79
#          Piastri         36

# %% [markdown]
# ✍🏻 **Problem 2, PEP-8**: In the [PEP-8 standard](https://peps.python.org/pep-0008/) for Python, are these true or false?
# * you should use a tab, rather than four spaces for indenting
# * there is no limit to how long a line should be
# * functions at the top of your code should be surrounded by a single line
# * imports should all be on the same line.

# %% [markdown]
# * False, you should use four spaces for indenting, not tabs. Tabs are not recommended for consistent code formatting.
# * False, each line of code should be limited to a maximum of 79 characters.
# * False, Functions at the top of your code should be surrounded by two blank lines.
# * False, Imports should not necessarily all be on the same line. PEP 8 recommends a specific order for organizing imports.

# %% [markdown]
# ✍🏻 **Problem 3. List Methods**: In a code cell, write code that performs these tasks:
# * sort the list `[3, 3, 1, 89, 0, 2]` in descending order,
# * add "z" to the end of the list `["w", "x", "y"]`, and then reverse the order,
# * insert "b" between the "a" and "c" in the list ["a", "c"].

# %%
l1 = [3,3,1,89,0,2]
l1 = sorted(l1, reverse=True)
print(l1)

l2 = ["w","x","y"]
l2.append("z")
l2.reverse()
print(l2)

l3 = ["a","c"]
l3.insert(1,"b")
print(l3)
# Out:
# [89, 3, 3, 2, 1, 0]
# ['z', 'y', 'x', 'w']
# ['a', 'b', 'c']

# %% [markdown]
# ✍🏻 **Problem 4. Web App Visualization**: Last week you built your first DS web app using `streamlit`. The web app used the Italian wine dataset from `sklearn` and made the plot using a visualization library called `Altair`. Modify your code to:
# * read the iris dataset from Seaborn,
# * rather than using `Altair`, use `Plotly`,
# * the interactive plot should be a 3D scatter plot,
# * update the text to describe this dataset.
#
# You already know how to get datasets from Seaborn. You may not have encountered `Plotly` before, however.
#
# [Here](https://docs.streamlit.io/library/api-reference/charts/st.plotly_chart) is how `Plotly` works with `streamlit`. [Read this page](https://docs.streamlit.io/library/api-reference/charts) to see all of the options that are available to you. For your project, you can choose from among all of these options!
#
# You will make many choices when you build your web app for your midterm project. Here we are exploring:
# * using different datasets,
# * using different visualization libraries,
#
# all within `streamlit`. Consider trying other datasets (e.g., mpg) and other visualization libraries (e.g., matplotlib) now.
#
# If you get stuck moving to a 3D scatter plot in `Plotly`, send a message on Slack for a hint.

# %% [markdown]
# ![Screenshot%202023-09-15%20at%2023.35.19.png](attachment:Screenshot%202023-09-15%20at%2023.35.19.png)

# %% [markdown]
# ✍🏻 **Problem 5, Data Structures**: In a markdown cell, describe each of these concepts and how they are related (or not).
# * unstructured data,
# * longitudinal data,
# * structured data,
# * data matrix,
# * panel data,
# * spatiotemporal data,
# * tidy data.

# %% [markdown]
# * Unstructured data refers to data that does not have a predefined structure. It does not fit neatly into traditional databases or tables. Examples include text data, images, audio, and video.
#
# * Longitudinal data, also known as time-series data, is data collected or observed over a period of time at multiple points. It typically involves tracking the same subjects, entities, or variables at different time intervals.
#
# * Structured data is data that is organized into a specific format, such as a table or a database. It is typically highly organized and can be easily processed by computers. Examples include spreadsheets and relational databases.
#
# * A data matrix is a two-dimensional representation of data where rows represent observations or samples, and columns represent variables or features. It is a common way to organize structured data for analysis.
#
# * Panel data, also known as longitudinal or cross-sectional time series data, combines aspects of time-series data and cross-sectional data. It involves multiple observations of the same entities (e.g., individuals or companies) over time.
#
# * Spatiotemporal data combines both spatial and temporal information. It represents data points in both space (location) and time (timestamps). This type of data is often used in applications like GPS tracking, climate modeling, and geospatial analysis.
#
# * Tidy data is a concept popularized by Hadley Wickham in his paper "Tidy Data." It refers to a specific way of organizing data in a tabular format where each variable has its own column, each observation has its own row, and each type of observational unit forms a table. Tidy data is designed to make data analysis and visualization more straightforward and consistent.
#
# These concepts are related to data organization and structure, but they represent different aspects and types of data. However, they are not mutually exclusive, and some relationships can exist. For example, structured data can be transformed into tidy data by reshaping it to adhere to the principles of tidy data and so on.

# %% [markdown]
# ✍🏻 **Problem 6, Pandas Methods**: This problem walks you through the steps to form a mask that selects portions of your data - a very general idea in data science. Here, we use the idea to clean the data. Go through this _very slowly_.
#
# Using the approach we have been using so far in this class, read in the penguins dataset into a dataframe (df).
#
# Once you have the dataset in a dataframe, visually inspect the df to see if there are any bad values, which will be called "NaN", for "not a number". Do you see any?
#
# Next, use `df.isna()` to see what it does. Describe what you see - what did it do?
#
# Read about the `any` command [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.any.html). In a code cell, put the command `df.isna().any(axis=1)` and describe what it is doing.
#
# One of the main observations so far is that the outputs are Booleans. Booleans play a big role in data science: they allow you to find patterns in the data and select based on those patterns.
#
# The way we get the final result is to select out of the original dataframe from the Booleans we created (which is a Series). We do this by putting the Booleans into `[]` after the name of the dataframe, as in `df[df.isna().any(axis=1)]`. Try this and describe what you see.
#
# Note that this is a bit tedious, which is why it is important that you understand each individual step. However, most often we simply want to drop these rows, not look at them. Finally, use [`dropna`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html) to drop all rows with NaNs. Look at the resulting dataframe to confirm you have a clean dataframe now. Use `.describe` on the original and the cleaned dataframe to see how many rows were lost and whether the statistics changed - what do you see?
#
# If this problem is very confusing because of the use of Boolean masks, [read this page](https://jakevdp.github.io/PythonDataScienceHandbook/02.06-boolean-arrays-and-masks.html). The use of masks for sorting and organizing is an _extremely_ powerful data tool in data science (as well as other areas). This is particularly powerful with Pandas dataframes, but there are equivalents in other libraries (e.g., NumPy).

# %%
import numpy as np
# Once you have the dataset in a dataframe, visually inspect the df to see if there are any bad values, which will be called "NaN", for "not a number". Do you see any?
df_penguin = sns.load_dataset("penguins")
df_penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# Yes, I do see NaN values in the dataset.

# %%
# Next, use df.isna() to see what it does. Describe what you see - what did it do?
df_penguin.isna()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# 3           True   True
# 4          False  False
# ..           ...    ...
# 339         True   True
# 340        False  False
# 341        False  False
# 342        False  False
# 343        False  False
#
# [344 rows x 7 columns]

# %% [markdown]
# This returned a table with boolean values where True means  the record has an NaN value and False means otherwise.

# %%
# Read about the any command here. In a code cell, put the command df.isna().any(axis=1) and describe what it is doing.
df_penguin.isna().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %% [markdown]
# It returns boolean values where True means that the whole row of records has atleast one NaN value and False means otherwise.

# %%
# The way we get the final result is to select out of the original dataframe from the Booleans we created (which is a Series). We do this by putting the Booleans into [] after the name of the dataframe, as in df[df.isna().any(axis=1)]. Try this and describe what you see.
df_penguin[df_penguin.isna().any(axis=1)]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN
# 336       4875.0  NaN
# 339          NaN  NaN

# %% [markdown]
# This returned all the rows which contained atleast one null value

# %%
# Creating a new dataset by dropping NaN values
df_peng_clean = df_penguin.dropna()
df_peng_clean
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
# Describing old dataset
df_penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# Describing new clean dataset
df_peng_clean.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# Comparing both the datasets we can see that the dropna() function dropped all the rows containing null values and dropped a total of 9 rows from the dataset. The stats changed a little because certain values which were not NaN were also dropped as they were in the same row as NaN values. Some actual values were dropped plus the number of records also changed which explains the change in stats.

# %% [markdown]
# ✍🏻 **Problem 7, Plotting in Pandas**: For the penguins dataset of the previous problem,
# * with Pandas, plot each of the four columns as Kernel Density Estimation plots,
# * using [scatter](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.scatter.html), plot bill depth versus length.
#
# Use `Pandas` for these plots, _not_ `matplotlib` or `Seaborn` or anything else.

# %%
import pandas.plotting as pd_plotting

#Plotting each column as KDE plots
pd_plotting.scatter_matrix(df_penguin[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']], diagonal='kde')

#Scatter plot, bill depth versus length
df_penguin.plot.scatter(x='bill_length_mm', y='bill_depth_mm', title='Scatter Plot: Bill Depth vs Bill Length')
# Out:
# <Axes: title={'center': 'Scatter Plot: Bill Depth vs Bill Length'}, xlabel='bill_length_mm', ylabel='bill_depth_mm'>
